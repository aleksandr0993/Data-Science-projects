# %% [markdown]
# # Оптимизация производственных расходов металлургического комбината

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных:</a></span><ul class="toc-item"><li><span><a href="#Описание-этапа-обработки" data-toc-modified-id="Описание-этапа-обработки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание этапа обработки</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Изучение-данных:" data-toc-modified-id="Изучение-данных:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных:</a></span><ul class="toc-item"><li><span><a href="#Изучаем-данные-по-таблице-data_arc" data-toc-modified-id="Изучаем-данные-по-таблице-data_arc-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучаем данные по таблице data_arc</a></span></li><li><span><a href="#При-похожих-средних-значениях,-у-реактивной-мощности-стандартное-отклонение-в-14-раз-выше,-чем-у-активной.-У-обеих-мощностей-минимальные-и-максимальные-значения-по-модулю-превышают-утроенное-стандартное-отклонение.-Удалим-аномалии-функцией-filt:" data-toc-modified-id="При-похожих-средних-значениях,-у-реактивной-мощности-стандартное-отклонение-в-14-раз-выше,-чем-у-активной.-У-обеих-мощностей-минимальные-и-максимальные-значения-по-модулю-превышают-утроенное-стандартное-отклонение.-Удалим-аномалии-функцией-filt:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>При похожих средних значениях, у реактивной мощности стандартное отклонение в 14 раз выше, чем у активной. У обеих мощностей минимальные и максимальные значения по модулю превышают утроенное стандартное отклонение. Удалим аномалии функцией filt:</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_bulk" data-toc-modified-id="Изучаем-данные-по-таблице-data_bulk-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изучаем данные по таблице data_bulk</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_bulk_time" data-toc-modified-id="Изучаем-данные-по-таблице-data_bulk_time-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изучаем данные по таблице data_bulk_time</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_gas" data-toc-modified-id="Изучаем-данные-по-таблице-data_gas-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Изучаем данные по таблице data_gas</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_temp" data-toc-modified-id="Изучаем-данные-по-таблице-data_temp-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Изучаем данные по таблице data_temp</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_wire" data-toc-modified-id="Изучаем-данные-по-таблице-data_wire-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Изучаем данные по таблице data_wire</a></span></li><li><span><a href="#Изучаем-данные-по-таблице-data_wire_time" data-toc-modified-id="Изучаем-данные-по-таблице-data_wire_time-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Изучаем данные по таблице data_wire_time</a></span></li><li><span><a href="#Агрегирование" data-toc-modified-id="Агрегирование-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Агрегирование</a></span></li></ul></li><li><span><a href="#Дальнейший-план-работы:" data-toc-modified-id="Дальнейший-план-работы:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Дальнейший план работы:</a></span></li><li><span><a href="#Обучение-на-различных-наборах-признаков" data-toc-modified-id="Обучение-на-различных-наборах-признаков-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение на различных наборах признаков</a></span><ul class="toc-item"><li><span><a href="#Добавляем-2-новых-признака:-сумма-материалов-по-Bulk-и-Wire" data-toc-modified-id="Добавляем-2-новых-признака:-сумма-материалов-по-Bulk-и-Wire-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Добавляем 2 новых признака: сумма материалов по Bulk и Wire</a></span></li><li><span><a href="#Далее-были-испробованы-3-разных-обучающих-выборки-:-с-активной-мощностью,-с-временем-наргева-в-сек.,-и-полная-работа-(результат-наилучшего-МАЕ---поверх-ячейки-с-кодом)" data-toc-modified-id="Далее-были-испробованы-3-разных-обучающих-выборки-:-с-активной-мощностью,-с-временем-наргева-в-сек.,-и-полная-работа-(результат-наилучшего-МАЕ---поверх-ячейки-с-кодом)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Далее были испробованы 3 разных обучающих выборки : с активной мощностью, с временем наргева в сек., и полная работа (результат наилучшего МАЕ - поверх ячейки с кодом)</a></span></li><li><span><a href="#Убираем-все-признаки-Bulk-1-15-и-Wire-1-9,-оставляем-фичи-Суммарных-Bulk-и-Wire" data-toc-modified-id="Убираем-все-признаки-Bulk-1-15-и-Wire-1-9,-оставляем-фичи-Суммарных-Bulk-и-Wire-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Убираем все признаки Bulk 1-15 и Wire 1-9, оставляем фичи Суммарных Bulk и Wire</a></span></li></ul></li><li><span><a href="#Линейная-регрессия-на-очищенных-от-выбросов-даннных" data-toc-modified-id="Линейная-регрессия-на-очищенных-от-выбросов-даннных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Линейная регрессия на очищенных от выбросов даннных</a></span></li><li><span><a href="#Дополнительные-модели" data-toc-modified-id="Дополнительные-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Дополнительные модели</a></span></li><li><span><a href="#Визуализация-с-TSNE-очищенного-от-выбросов-датафрейма-(раскраска-по-диапазону-начальной-температуры)" data-toc-modified-id="Визуализация-с-TSNE-очищенного-от-выбросов-датафрейма-(раскраска-по-диапазону-начальной-температуры)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Визуализация с TSNE очищенного от выбросов датафрейма (раскраска по диапазону начальной температуры)</a></span></li><li><span><a href="#Визуализация-с-TSNE-неочищенного-от-выбросов-датафрейма-(раскраска-по-диапазону-конечной-температуры)" data-toc-modified-id="Визуализация-с-TSNE-неочищенного-от-выбросов-датафрейма-(раскраска-по-диапазону-конечной-температуры)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Визуализация с TSNE неочищенного от выбросов датафрейма (раскраска по диапазону конечной температуры)</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Вывод:</a></span><ul class="toc-item"><li><span><a href="#В-результате-работы-над-проектом-выполнены-пункты-по:" data-toc-modified-id="В-результате-работы-над-проектом-выполнены-пункты-по:-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>В результате работы над проектом выполнены пункты по:</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание данных:
# Чтобы оптимизировать производственные расходы, металлургический комбинат решил уменьшить потребление электроэнергии на этапе обработки стали. Нужно построить модель для предсказания температуры стали.

# %% [markdown]
# ### Описание этапа обработки
#
# Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# Из сплава выводится сера (десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (англ. tribe, «масса»).
#
# Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (англ. *slab*, «плита»).

# %% [markdown]
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `data_arc.csv` — данные об электродах;
# - `data_bulk.csv` — данные о подаче сыпучих материалов (объём);
# - `data_bulk_time.csv` *—* данные о подаче сыпучих материалов (время);
# - `data_gas.csv` — данные о продувке сплава газом;
# - `data_temp.csv` — результаты измерения температуры;
# - `data_wire.csv` — данные о проволочных материалах (объём);
# - `data_wire_time.csv` — данные о проволочных материалах (время).

# %% [markdown]
# ## Изучение данных:

# %%
import lightgbm as lgbm
import numpy as np
import sklearn
import pandas as pd
import math
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import OrdinalEncoder
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import mlxtend

# %% [markdown]
# ### Изучаем данные по таблице data_arc

# %%
data_arc = pd.read_csv('/Users/a1234/Downloads/final_steel/data_arc.csv')
data_arc.head()
# Out:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.976059
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.805607
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.744363
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           1.659363
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.692755
#
#    Реактивная мощность
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397

# %%
pd.Series(data_arc['key'].unique()).count()
# Out:
# 3214

# %%
data_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB

# %%
data_arc['Начало нагрева дугой'] = pd.to_datetime(data_arc['Начало нагрева дугой'])
data_arc['Конец нагрева дугой'] = pd.to_datetime(data_arc['Конец нагрева дугой'])

# %%
data_arc['diff'] = (data_arc['Конец нагрева дугой'] - data_arc['Начало нагрева дугой'])
data_arc['diff'] = data_arc['diff'].dt.seconds

# %%
data_arc.describe()
# Out:
#                 key  Активная мощность  Реактивная мощность          diff
# count  14876.000000       14876.000000         14876.000000  14876.000000
# mean    1615.220422           0.670441             0.452592    171.670946
# std      934.571502           0.408159             5.878702     98.186803
# min        1.000000           0.030002          -715.504924     11.000000
# 25%      806.000000           0.395297             0.290991    107.000000
# 50%     1617.000000           0.555517             0.415962    147.000000
# 75%     2429.000000           0.857034             0.637371    214.000000
# max     3241.000000           3.731596             2.676388    907.000000

# %% [markdown]
# ### При похожих средних значениях, у реактивной мощности стандартное отклонение в 14 раз выше, чем у активной. У обеих мощностей минимальные и максимальные значения по модулю превышают утроенное стандартное отклонение. Удалим аномалии функцией filt:

# %%
def filt(l, h, df, features):
    for i in features:
        low =  df[i].quantile(l)
        high = df[i].quantile(h)

        df = df[(df[i]>= low) & (df[i]<= high)]

    return df

# %%
#data_arc = filt(0.005, 0.995, data_arc, ['Активная мощность', 'Реактивная мощность', 'diff']) #, 'diff'

# %%
data_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  datetime64[ns]
#  2   Конец нагрева дугой   14876 non-null  datetime64[ns]
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
#  5   diff                  14876 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(2)
# memory usage: 697.4 KB

# %% [markdown]
# ### Изучаем данные по таблице data_bulk

# %%
data_bulk = pd.read_csv('/Users/a1234/Downloads/final_steel/data_bulk.csv')
data_bulk.head()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
data_bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB

# %%
pd.Series(data_bulk['key'].unique()).count()
# Out:
# 3129

# %%
data_bulk.describe()
# Out:
#                key      Bulk 1      Bulk 2       Bulk 3       Bulk 4  \
# count  3129.000000  252.000000   22.000000  1298.000000  1014.000000
# mean   1624.383509   39.242063  253.045455   113.879045   104.394477
# std     933.337642   18.277654   21.180578    75.483494    48.184126
# min       1.000000   10.000000  228.000000     6.000000    12.000000
# 25%     816.000000   27.000000  242.000000    58.000000    72.000000
# 50%    1622.000000   31.000000  251.500000    97.500000   102.000000
# 75%    2431.000000   46.000000  257.750000   152.000000   133.000000
# max    3241.000000  185.000000  325.000000   454.000000   281.000000
#
#            Bulk 5      Bulk 6      Bulk 7  Bulk 8      Bulk 9     Bulk 10  \
# count   77.000000  576.000000   25.000000     1.0   19.000000  176.000000
# mean   107.025974  118.925347  305.600000    49.0   76.315789   83.284091
# std     81.790646   72.057776  191.022904     NaN   21.720581   26.060347
# ...

# %%
plt.figure(figsize=(15,10))
plt.xlim(0, 800)
sns.boxplot(data=data_bulk.drop('key', axis=1), orient="h", palette="Set2")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим, что у всех bulk распределения различны.

# %%
#data_bulk = filt(0.005, 0.995, data_bulk, [i for i in data_bulk.columns[1:]])

# %%
data_bulk = data_bulk.fillna(0)

# %% [markdown]
# Фильтрацию не проводим, т.к. исходный датасет имел много пропусков.

# %% [markdown]
# ### Изучаем данные по таблице data_bulk_time

# %%
data_bulk_time = pd.read_csv('/Users/a1234/Downloads/final_steel/data_bulk_time.csv')
data_bulk_time.head()
# Out:
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaN    NaN    NaN  2019-05-03 11:21:30    NaN    NaN    NaN    NaN
# 1    2    NaN    NaN    NaN  2019-05-03 11:46:38    NaN    NaN    NaN    NaN
# 2    3    NaN    NaN    NaN  2019-05-03 12:31:06    NaN    NaN    NaN    NaN
# 3    4    NaN    NaN    NaN  2019-05-03 12:48:43    NaN    NaN    NaN    NaN
# 4    5    NaN    NaN    NaN  2019-05-03 13:18:50    NaN    NaN    NaN    NaN
#
#   Bulk 9 Bulk 10 Bulk 11              Bulk 12 Bulk 13              Bulk 14  \
# 0    NaN     NaN     NaN  2019-05-03 11:03:52     NaN  2019-05-03 11:03:52
# 1    NaN     NaN     NaN  2019-05-03 11:40:20     NaN  2019-05-03 11:40:20
# 2    NaN     NaN     NaN  2019-05-03 12:09:40     NaN  2019-05-03 12:09:40
# 3    NaN     NaN     NaN  2019-05-03 12:41:24     NaN  2019-05-03 12:41:24
# 4    NaN     NaN     NaN  2019-05-03 13:12:56     NaN  2019-05-03 13:12:56
#
#                Bulk 15
# 0  2019-05-03 11:03:52
# ...

# %%
for i in data_bulk_time.columns[1:]:    
    data_bulk_time = data_bulk_time.rename(columns={i:i+'_t'})

# %%
pd.Series(data_bulk_time['key'].unique()).count()
# Out:
# 3129

# %%
data_bulk_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   key        3129 non-null   int64
#  1   Bulk 1_t   252 non-null    object
#  2   Bulk 2_t   22 non-null     object
#  3   Bulk 3_t   1298 non-null   object
#  4   Bulk 4_t   1014 non-null   object
#  5   Bulk 5_t   77 non-null     object
#  6   Bulk 6_t   576 non-null    object
#  7   Bulk 7_t   25 non-null     object
#  8   Bulk 8_t   1 non-null      object
#  9   Bulk 9_t   19 non-null     object
#  10  Bulk 10_t  176 non-null    object
#  11  Bulk 11_t  177 non-null    object
#  12  Bulk 12_t  2450 non-null   object
#  13  Bulk 13_t  18 non-null     object
#  14  Bulk 14_t  2806 non-null   object
#  15  Bulk 15_t  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB

# %%
data_bulk_time.iloc[:, 1:] = data_bulk_time.iloc[:, 1:].apply(pd.to_datetime)

# %%
data_bulk_time.head()
# Out:
#    key Bulk 1_t Bulk 2_t Bulk 3_t            Bulk 4_t Bulk 5_t Bulk 6_t  \
# 0    1      NaT      NaT      NaT 2019-05-03 11:21:30      NaT      NaT
# 1    2      NaT      NaT      NaT 2019-05-03 11:46:38      NaT      NaT
# 2    3      NaT      NaT      NaT 2019-05-03 12:31:06      NaT      NaT
# 3    4      NaT      NaT      NaT 2019-05-03 12:48:43      NaT      NaT
# 4    5      NaT      NaT      NaT 2019-05-03 13:18:50      NaT      NaT
#
#   Bulk 7_t Bulk 8_t Bulk 9_t Bulk 10_t Bulk 11_t           Bulk 12_t  \
# 0      NaT      NaT      NaT       NaT       NaT 2019-05-03 11:03:52
# 1      NaT      NaT      NaT       NaT       NaT 2019-05-03 11:40:20
# 2      NaT      NaT      NaT       NaT       NaT 2019-05-03 12:09:40
# 3      NaT      NaT      NaT       NaT       NaT 2019-05-03 12:41:24
# 4      NaT      NaT      NaT       NaT       NaT 2019-05-03 13:12:56
#
#   Bulk 13_t           Bulk 14_t           Bulk 15_t
# 0       NaT 2019-05-03 11:03:52 2019-05-03 11:03:52
# ...

# %% [markdown]
# ### Изучаем данные по таблице data_gas

# %%
data_gas = pd.read_csv('/Users/a1234/Downloads/final_steel/data_gas.csv')
data_gas.head()
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
data_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
pd.Series(data_gas['key'].unique()).count()
# Out:
# 3239

# %%
data_gas.describe()
# Out:
#                key        Газ 1
# count  3239.000000  3239.000000
# mean   1621.861377    11.002062
# std     935.386334     6.220327
# min       1.000000     0.008399
# 25%     812.500000     7.043089
# 50%    1622.000000     9.836267
# 75%    2431.500000    13.769915
# max    3241.000000    77.995040

# %%
#data_gas = filt(0.005, 0.995, data_gas, ['Газ 1'])

# %%
sns.distplot(data_gas['Газ 1'])
# Out:
# <AxesSubplot:xlabel='Газ 1', ylabel='Density'>

# %% [markdown]
# ### Изучаем данные по таблице data_temp

# %%
data_temp = pd.read_csv('/Users/a1234/Downloads/final_steel/data_temp.csv')
data_temp.head(6)
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0

# %%
data_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           15907 non-null  int64
#  1   Время замера  15907 non-null  object
#  2   Температура   13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB

# %%
data_temp['Время замера'] = pd.to_datetime(data_temp['Время замера'])

# %%
(data_temp.groupby('key')['Температура'].sum() == 0).value_counts()
# Out:
# False    3216
# Name: Температура, dtype: int64

# %%
pd.Series(data_temp['key'].unique()).count()
# Out:
# 3216

# %%
round(12762/3193)
# Out:
# 4

# %% [markdown]
# На одну партию имеем в среднем 4 замера температуры.

# %%
data_temp.loc[:4, 'Температура'].min()
# Out:
# 1571.0

# %%
import matplotlib.ticker as ticker
y_min = data_temp.loc[:4, 'Температура'].min()
y_max = data_temp.loc[:4, 'Температура'].max()
ax = data_temp.head().plot()
plt.ylim(y_min, y_max)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

# %%
data_temp.describe()
# Out:
#                 key   Температура
# count  15907.000000  13006.000000
# mean    1607.880870   1591.840920
# std      942.212073     21.375851
# min        1.000000   1191.000000
# 25%      790.000000   1581.000000
# 50%     1618.000000   1591.000000
# 75%     2427.000000   1601.000000
# max     3241.000000   1705.000000

# %%
#data_temp = filt(0.05, 0.95, data_temp, ['Температура'])

# %%
sns.distplot(data_temp['Температура'])
# Out:
# <AxesSubplot:xlabel='Температура', ylabel='Density'>

# %% [markdown]
# ### Изучаем данные по таблице data_wire

# %%
data_wire = pd.read_csv('/Users/a1234/Downloads/final_steel/data_wire.csv')
data_wire.head()
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
data_wire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB

# %%
pd.Series(data_wire['key'].unique()).count()
# Out:
# 3081

# %%
data_wire.describe()
# Out:
#                key       Wire 1       Wire 2      Wire 3      Wire 4  Wire 5  \
# count  3081.000000  3055.000000  1079.000000   63.000000   14.000000   1.000
# mean   1623.426485   100.895853    50.577323  189.482681   57.442842  15.132
# std     932.996726    42.012518    39.320216   99.513444   28.824667     NaN
# min       1.000000     1.918800     0.030160    0.144144   24.148801  15.132
# 25%     823.000000    72.115684    20.193680   95.135044   40.807002  15.132
# 50%    1619.000000   100.158234    40.142956  235.194977   45.234282  15.132
# 75%    2434.000000   126.060484    70.227558  276.252014   76.124619  15.132
# max    3241.000000   330.314424   282.780152  385.008668  113.231044  15.132
#
#            Wire 6     Wire 7      Wire 8     Wire 9
# count   73.000000  11.000000   19.000000  29.000000
# mean    48.016974  10.039007   53.625193  34.155752
# std     33.919845   8.610584   16.881728  19.931616
# min      0.034320   0.234208   45.076721   4.622800
# ...

# %%
plt.figure(figsize=(15,10))
plt.xlim(0, 400)
sns.boxplot(data=data_wire.drop('key', axis=1), orient="h", palette="Set2")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим, что у всех Wire распределения различны.

# %%
#data_wire = filt(0.005, 0.995, data_wire, [i for i in data_wire.columns[1:]]) - обнуляет

# %%
data_wire = data_wire.fillna(0)

# %% [markdown]
# ### Изучаем данные по таблице data_wire_time

# %%
data_wire_time = pd.read_csv('/Users/a1234/Downloads/final_steel/data_wire_time.csv')
data_wire_time.head()
# Out:
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:11:41                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:46:10                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:13:47                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:48:05                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:18:15  2019-05-03 13:32:06    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# 4    NaN    NaN    NaN

# %%
pd.Series(data_wire_time['key'].unique()).count()
# Out:
# 3081

# %%
data_wire_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB

# %%
for i in data_wire_time.columns[1:]:    
    data_wire_time = data_wire_time.rename(columns={i:i+'_t'})

# %%
data_wire_time.iloc[:, 1:] = data_wire_time.iloc[:, 1:].apply(pd.to_datetime)

# %%
data_wire_time.describe()
# Out:
#                key
# count  3081.000000
# mean   1623.426485
# std     932.996726
# min       1.000000
# 25%     823.000000
# 50%    1619.000000
# 75%    2434.000000
# max    3241.000000

# %% [markdown]
# ### Агрегирование

# %%
data_arc2 = data_arc.groupby('key').sum()
data_arc2.head()
# Out:
#      Активная мощность  Реактивная мощность  diff
# key
# 1             4.878147             3.183241  1098
# 2             3.052598             1.998112   811
# 3             2.525882             1.599076   655
# 4             3.209250             2.060298   741
# 5             3.347173             2.252643   869

# %%
data_temp_first = data_temp.groupby('key').head(1)
data_temp_last = data_temp.groupby('key').tail(1)

data_temp_first.head()
# Out:
#     key        Время замера  Температура
# 0     1 2019-05-03 11:16:18       1571.0
# 5     2 2019-05-03 11:37:27       1581.0
# 11    3 2019-05-03 12:13:17       1596.0
# 16    4 2019-05-03 12:52:57       1601.0
# 19    5 2019-05-03 13:23:19       1576.0

# %%
data_temp_first = data_temp_first.rename(columns={'Температура':'Температура_нач', 'Время замера':'Время замера_нач'}) #.drop('Время замера', axis=1)
data_temp_last = data_temp_last.rename(columns={'Температура':'Температура_кон', 'Время замера':'Время замера_кон'}) #.drop('Время замера', axis=1)

# %%
df = data_arc2.join(data_bulk.set_index('key', drop=True), how='outer')

# %%
for i in [data_bulk_time, data_gas, data_temp_first, data_temp_last, data_wire, data_wire_time]:
    i = i.set_index('key', drop=True)
    df = df.join(i, how='outer')

# %%
df.head()
# Out:
#      Активная мощность  Реактивная мощность    diff  Bulk 1  Bulk 2  Bulk 3  \
# key
# 1             4.878147             3.183241  1098.0     0.0     0.0     0.0
# 2             3.052598             1.998112   811.0     0.0     0.0     0.0
# 3             2.525882             1.599076   655.0     0.0     0.0     0.0
# 4             3.209250             2.060298   741.0     0.0     0.0     0.0
# 5             3.347173             2.252643   869.0     0.0     0.0     0.0
#
#      Bulk 4  Bulk 5  Bulk 6  Bulk 7  ...  Wire 9            Wire 1_t  \
# key                                  ...
# 1      43.0     0.0     0.0     0.0  ...     0.0 2019-05-03 11:11:41
# 2      73.0     0.0     0.0     0.0  ...     0.0 2019-05-03 11:46:10
# 3      34.0     0.0     0.0     0.0  ...     0.0 2019-05-03 12:13:47
# 4      81.0     0.0     0.0     0.0  ...     0.0 2019-05-03 12:48:05
# 5      78.0     0.0     0.0     0.0  ...     0.0 2019-05-03 13:18:15
#
# ...

# %%
time_cols = [i for i in df.columns if df[i].dtype == 'datetime64[ns]']

# %%
for i in df.index:
    if df.loc[i:i,time_cols].max(axis=1)[i] != df.loc[i:i, 'Время замера_кон'][i]:
        df = df.drop(i)

# %%
df = df.drop(columns=time_cols, axis=1)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[['Активная мощность', 'Реактивная мощность',
                'diff', 'Bulk 3', 'Газ 1', 'Температура_нач', 'Температура_кон', 'Wire 1']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['Активная мощность',  'diff', 'Bulk 3', 'Газ 1', 'Температура_нач', 'Температура_кон', 'Wire 1']])

# %% [markdown]
# Видим, что целевая переменная и начальная температура линейно зависимы.

# %% [raw]
# df = pd.concat([data_arc2, data_bulk.set_index('key', drop=True),
#                 data_bulk_time.set_index('key', drop=True), data_gas.set_index('key', drop=True)
#                 , data_temp.set_index('key', drop=True)
#                 , data_wire.set_index('key', drop=True), data_wire_time.set_index('key', drop=True)], axis=0, join='outer')
# df.head()

# %% [markdown]
# Вывод: проведена очистка данных от выбросов, некоторые пропущенные значения заполнены нулями. Данные визуализированы. Таблицы объединены в одну сводную.

# %% [markdown]
# ## Дальнейший план работы:

# %% [markdown]
# - Удаление значений целевого признака (конечной температуры) в том случае, если после замера были проведены прочие манипуляции (введение добавок, газа, нагревание). Для поиска будут использованы времена из разных таблиц.
# - Построить различные модели машинного обучения и оценить их качество на отложенной выборке по метрике MAE
# - Провести отбор признаков и определить их важность
# - Пробовать модели с разными признаками: активная мощность или полная мощность, или полная работа
# - Суммирование всех ресурсов по партии и использование этого, как новый признак
# - Выбор наилучшей модели, опираясь на наименьшее значение MAE на кросс-валидации

# %% [markdown]
# ## Обучение на различных наборах признаков

# %% [markdown]
# Удаляем всю партию при при удалении пустот в целевой переменной

# %%
df = df.dropna(subset=['Температура_кон'])

# %% [markdown]
# ### Добавляем 2 новых признака: сумма материалов по Bulk и Wire

# %%
df['Bulk_total'] =  df[[x for x in df.columns if 'Bulk ' in x]].sum(axis=1)
df['Wire_total'] =  df[[x for x in df.columns if 'Wire ' in x]].sum(axis=1)

# %%
df = df.fillna(0)

# %% [markdown]
# ### Далее были испробованы 3 разных обучающих выборки : с активной мощностью, с временем наргева в сек., и полная работа (результат наилучшего МАЕ - поверх ячейки с кодом)

# %%
#6.28
X = df.drop(['Температура_кон', 'diff', 'Реактивная мощность'], axis=1)
y = df['Температура_кон']
X.shape, y.shape
# Out:
# ((2468, 29), (2468,))

# %% [raw]
# #6.6
# X = df.drop(['Температура_кон', 'Активная мощность'], axis=1)
# y = df['Температура_кон']
# X.shape, y.shape

# %% [raw]
# ## удалось достичь МАЕ около 7
# df2 = df.copy()
# df2['Работа'] = df2['Активная мощность'] * df2['diff']
# X = df2.drop(['Температура_кон', 'diff', 'Активная мощность', 'Температура_нач'], axis=1)
# y = df2['Температура_кон']
# X.shape, y.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12345)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1851, 21), (1851,), (617, 21), (617,))

# %%
def eval(model, params):
    grid = GridSearchCV(model, param_grid=params, scoring='neg_mean_absolute_error', n_jobs=-1, cv=5)
    grid.fit(X_train, y_train)
    pred = grid.predict(X_test)                                                   
    print('MAE:', -grid.best_score_)
    print('Best params:',grid.best_params_)

# %%
# %%time
model = LinearRegression()
eval(model, {'normalize':[True, False], 'fit_intercept':[True, False]})
# Out:
# MAE: 5.983419597893907
# Best params: {'fit_intercept': True, 'normalize': False}
# CPU times: user 60.2 ms, sys: 9.88 ms, total: 70.1 ms
# Wall time: 79.5 ms

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'max_depth':[np.arange(2, 12, 1),  None]})
# Out:
# MAE: 6.176030303030304
# Best params: {'max_depth': None}
# CPU times: user 6.5 s, sys: 327 ms, total: 6.82 s
# Wall time: 7.61 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'min_samples_split':np.arange(2, 12, 1)})
# Out:
# MAE: 6.153888900864348
# Best params: {'min_samples_split': 11}
# CPU times: user 5.08 s, sys: 255 ms, total: 5.33 s
# Wall time: 42.2 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1, min_samples_split=4)
eval(model, {'min_samples_leaf':np.arange(1, 30, 10)})
# Out:
# MAE: 6.056340023946314
# Best params: {'min_samples_leaf': 11}
# CPU times: user 3.3 s, sys: 236 ms, total: 3.53 s
# Wall time: 10.5 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1, min_samples_split=4)
eval(model, {'min_samples_leaf':np.arange(1, 30, 10)})
# Out:
# MAE: 6.056340023946314
# Best params: {'min_samples_leaf': 11}
# CPU times: user 3.79 s, sys: 316 ms, total: 4.11 s
# Wall time: 10.4 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1, min_samples_split=4)
eval(model, {'max_features':['auto', 'sqrt', 'log2']})
# Out:
# MAE: 6.125727619493316
# Best params: {'max_features': 'log2'}
# CPU times: user 1.81 s, sys: 368 ms, total: 2.18 s
# Wall time: 8.88 s

# %%
# %%time
model = LGBMRegressor(n_estimators=300, random_state=12345, n_jobs=-1)
eval(model, {'learning_rate':np.arange(0.01, 1, 0.01)})
# Out:
# MAE: 6.03928282009589
# Best params: {'learning_rate': 0.01}
# CPU times: user 8.01 s, sys: 1.09 s, total: 9.1 s
# Wall time: 38.1 s

# %%
# %%time
model = LGBMRegressor(n_estimators=300, random_state=12345, n_jobs=-1, learning_rate=0.02)
eval(model, {'max_depth':[np.arange(2, 20, 1),  None]})
# Out:
# MAE: 6.146264258017851
# Best params: {'max_depth': None}
# CPU times: user 6.4 s, sys: 960 ms, total: 7.36 s
# Wall time: 1.6 s

# %%
# %%time
model = LGBMRegressor(random_state=12345, learning_rate=0.02, n_jobs=-1, n_estimators=300)
eval(model, {'reg_alpha':np.arange(0, 10, 1)})
# Out:
# MAE: 6.093222551668854
# Best params: {'reg_alpha': 8}
# CPU times: user 6.61 s, sys: 929 ms, total: 7.54 s
# Wall time: 5.73 s

# %%
# %%time
model = LGBMRegressor(n_estimators=300, random_state=12345, learning_rate=0.02, n_jobs=-1, reg_alpha=6)
eval(model, {'reg_lambda':np.arange(0, 10, 1)})
# Out:
# MAE: 6.076825984584727
# Best params: {'reg_lambda': 4}
# CPU times: user 6.81 s, sys: 1.2 s, total: 8.01 s
# Wall time: 6.64 s

# %%
# %%time
model = LGBMRegressor(n_estimators=300, random_state=12345, learning_rate=0.02, n_jobs=-1, reg_alpha=6)
eval(model, {'num_leaves':np.arange(10, 30, 1)})
# Out:
# MAE: 5.99538604122564
# Best params: {'num_leaves': 10}
# CPU times: user 2.8 s, sys: 408 ms, total: 3.21 s
# Wall time: 7.85 s

# %%
feature_names = X_train.columns 
forest = RandomForestRegressor(n_estimators=500, random_state=12345, n_jobs=-1)
forest.fit(X_train, y_train)
pred = forest.predict(X_test)
importances = forest.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)

std = np.std([forest.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# ### Убираем все признаки Bulk 1-15 и Wire 1-9, оставляем фичи Суммарных Bulk и Wire

# %%
X = df.drop(['Температура_кон', 'diff'], axis=1)
X = X.drop([x for x in df.columns if 'Bulk ' in x], axis=1)
X = X.drop([x for x in df.columns if 'Wire ' in x], axis=1)
y = df['Температура_кон']
X.shape, y.shape
# Out:
# ((2468, 7), (2468,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12345)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1851, 7), (1851,), (617, 7), (617,))

# %%
# %%time
model = LinearRegression()
eval(model, {'normalize':[True, False], 'fit_intercept':[True, False]})
# Out:
# MAE: 9.540143458632878
# Best params: {'fit_intercept': True, 'normalize': True}
# CPU times: user 53.4 ms, sys: 6.75 ms, total: 60.1 ms
# Wall time: 64.5 ms

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'min_samples_split':np.arange(2, 12, 1)})
# Out:
# MAE: 6.618585660327554
# Best params: {'min_samples_split': 11}
# CPU times: user 4.77 s, sys: 240 ms, total: 5.01 s
# Wall time: 40.9 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1, min_samples_split=7)
eval(model, {'min_samples_leaf':np.arange(1, 30, 10)})
# Out:
# MAE: 6.637389619448591
# Best params: {'min_samples_leaf': 1}
# CPU times: user 5.23 s, sys: 281 ms, total: 5.51 s
# Wall time: 10.8 s

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, n_jobs=-1)
eval(model, {'learning_rate':np.arange(0.01, 1, 0.01)})
# Out:
# MAE: 6.663434155293617
# Best params: {'learning_rate': 0.05}
# CPU times: user 2.82 s, sys: 300 ms, total: 3.12 s
# Wall time: 11.4 s

# %%
# %%time
model = LGBMRegressor(random_state=12345, learning_rate=0.06, n_jobs=-1, n_estimators=100)
eval(model, {'reg_alpha':np.arange(0, 20, 1)})
# Out:
# MAE: 6.685099897542045
# Best params: {'reg_alpha': 2}
# CPU times: user 2.22 s, sys: 413 ms, total: 2.63 s
# Wall time: 3.61 s

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.04, n_jobs=-1)
eval(model, {'reg_lambda':np.arange(0, 50, 5)})
# Out:
# MAE: 6.688406489067023
# Best params: {'reg_lambda': 0}
# CPU times: user 2.08 s, sys: 343 ms, total: 2.42 s
# Wall time: 1.65 s

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.04, n_jobs=-1)
eval(model, {'num_leaves':np.arange(2, 60, 2)})
# Out:
# MAE: 6.683908033755498
# Best params: {'num_leaves': 30}
# CPU times: user 2.2 s, sys: 317 ms, total: 2.52 s
# Wall time: 3.55 s

# %%
feature_names = X_train.columns 
forest = RandomForestRegressor(n_estimators=500, random_state=12345, n_jobs=-1)
forest.fit(X_train, y_train)
pred = forest.predict(X_test)
importances = forest.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)

std = np.std([forest.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
# %%time
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS



#model = LGBMRegressor(random_state=12345, n_jobs=-1, learning_rate = 0.04)
model = RandomForestRegressor(n_estimators=100, random_state=12345, n_jobs=-1)
efs1 = EFS(model, 
           min_features=1,
           max_features=6,
           scoring='neg_mean_absolute_error', #neg_root_mean_squared_error
           print_progress=True,
           cv=5)

efs1 = efs1.fit(X, y)

print('Best accuracy score: %.2f' % -efs1.best_score_)
print('Best subset (indices):', efs1.best_idx_)
print('Best subset (corresponding names):', efs1.best_feature_names_)
# Out:
# Features: 126/126
# Best accuracy score: 6.75
# Best subset (indices): (0, 2, 3, 4, 5, 6)
# Best subset (corresponding names): ('Активная мощность', 'Газ 1', 'Температура_нач', 'Bulk_total', 'Wire_total', 'Temp_last_type')
# CPU times: user 1min 49s, sys: 22.5 s, total: 2min 12s
# Wall time: 2min 34s

# %% [markdown]
# ## Линейная регрессия на очищенных от выбросов даннных

# %%
df2 = filt(0.035, 0.995, df, [i for i in df.drop(['Температура_кон'], axis=1).columns[1:]])
#df2 = filt(0, 0.99, df, [i for i in df.columns[1:]])

# %%
#6.28
X = df2.drop(['Температура_кон',  'Реактивная мощность', 'diff'], axis=1)
#df2 = filt(0, 0.99, df, [i for i in df.columns[1:]])
y = df2['Температура_кон']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12345)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1319, 30), (1319,), (440, 30), (440,))

# %%
# %%time
model = LinearRegression()
eval(model, {'normalize':[True, False], 'fit_intercept':[True, False]})
# Out:
# MAE: 5.726710979666717
# Best params: {'fit_intercept': True, 'normalize': False}
# CPU times: user 67.7 ms, sys: 15 ms, total: 82.7 ms
# Wall time: 78.1 ms

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, n_jobs=-1)
eval(model, {'learning_rate':np.arange(0.01, 1, 0.01)})
# Out:
# MAE: 5.675394262534292
# Best params: {'learning_rate': 0.05}
# CPU times: user 3.27 s, sys: 484 ms, total: 3.75 s
# Wall time: 14.2 s

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.03, n_jobs=-1)
eval(model, {'num_leaves':np.arange(2, 60, 2)})
# Out:
# MAE: 5.614072815034442
# Best params: {'num_leaves': 18}
# CPU times: user 1.81 s, sys: 261 ms, total: 2.08 s
# Wall time: 3.69 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'max_depth':[np.arange(2, 12, 1),  None]})
# Out:
# MAE: 5.813307794676804
# Best params: {'max_depth': None}
# CPU times: user 6.32 s, sys: 297 ms, total: 6.62 s
# Wall time: 6.69 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'min_samples_split':np.arange(2, 12, 1)})
# Out:
# MAE: 5.792220431033831
# Best params: {'min_samples_split': 11}
# CPU times: user 5.09 s, sys: 247 ms, total: 5.33 s
# Wall time: 42.8 s

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1, min_samples_split=9)
eval(model, {'min_samples_leaf':np.arange(1, 30, 10)})
# Out:
# MAE: 5.773275799447987
# Best params: {'min_samples_leaf': 11}
# CPU times: user 3.78 s, sys: 256 ms, total: 4.04 s
# Wall time: 10.2 s

# %%
feature_names = X_train.columns 
forest = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.03, num_leaves=14, n_jobs=-1)
forest.fit(X_train, y_train)
pred = forest.predict(X_test)
importances = forest.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)

std = np.std([forest.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# - Самыми важными признаками в лучшей модели являются Активная мощность, Температура начальная по партии, Bulk_6, Wire_1, Газ_1.

# %% [markdown]
# ## Дополнительные модели

# %%
sns.distplot(df['Температура_нач'])
# Out:
# <AxesSubplot:xlabel='Температура_нач', ylabel='Density'>

# %%
#Создадим новый признак: по диапазонам начальной температуры
df2['Temp_type'] = df2['Температура_нач'].apply(lambda x: 0 if x<1575 or x>1660
                                                      else 1)

# %%
sns.jointplot(data=df2, x="Температура_нач", y="Температура_кон", hue='Temp_type')

# %%
X = df2.drop(['Температура_кон', 'Температура_нач',  'Реактивная мощность', 'diff'], axis=1)
y = df2['Температура_кон']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12345)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1319, 30), (1319,), (440, 30), (440,))

# %%
# %%time
model = LinearRegression()
eval(model, {'normalize':[True, False], 'fit_intercept':[True, False]})
# Out:
# MAE: 6.029347620957494
# Best params: {'fit_intercept': True, 'normalize': True}
# CPU times: user 49.9 ms, sys: 7.1 ms, total: 57 ms
# Wall time: 68.2 ms

# %%
# %%time
model = RandomForestRegressor(random_state=12345, n_estimators=500, n_jobs=-1)
eval(model, {'min_samples_split':np.arange(2, 12, 1)})
# Out:
# MAE: 6.111064185677725
# Best params: {'min_samples_split': 11}
# CPU times: user 5 s, sys: 286 ms, total: 5.29 s
# Wall time: 40.8 s

# %%
# %%time
model = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.03, n_jobs=-1)
eval(model, {'num_leaves':np.arange(2, 60, 2)})
# Out:
# MAE: 5.943416896101006
# Best params: {'num_leaves': 12}
# CPU times: user 1.44 s, sys: 216 ms, total: 1.65 s
# Wall time: 3.83 s

# %%
feature_names = X_train.columns 
forest = LGBMRegressor(n_estimators=100, random_state=12345, learning_rate=0.03, num_leaves=14, n_jobs=-1)
forest.fit(X_train, y_train)
pred = forest.predict(X_test)
importances = forest.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)

std = np.std([forest.feature_importances_ for tree in str(1000)], axis=0)

fig, ax = plt.subplots(figsize=(10,7))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# ## Визуализация с TSNE очищенного от выбросов датафрейма (раскраска по диапазону начальной температуры)

# %%
# %%time
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

tsne = TSNE(random_state=17)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# CPU times: user 51.5 s, sys: 7.51 s, total: 59 s
# Wall time: 10.9 s

# %%
#смотрим где кучкуются признаки, разбитые по диапазонам начальной температуры
plt.figure(figsize=(10,8))
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=df2['Temp_type'].map({0: 'blue', 1: 'orange'}));

# %% [markdown]
# ## Визуализация с TSNE неочищенного от выбросов датафрейма (раскраска по диапазону конечной температуры)

# %%
#Создадим новый признак: по диапазонам конечной температуры
df['Temp_last_type'] = df['Температура_кон'].apply(lambda x: 0 if x<1630
                                                      else 1)
sns.jointplot(data=df, x="Температура_нач", y="Температура_кон", hue='Temp_last_type')

# %%
X = df.drop(['Температура_кон', 'diff', 'Реактивная мощность'], axis=1)
X_scaled = scaler.fit_transform(X)

tsne = TSNE(random_state=17)
tsne_representation = tsne.fit_transform(X_scaled)

# %%
#смотрим где кучкуются признаки, разбитые по диапазонам конечной температуры
plt.figure(figsize=(10,8))
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=df['Temp_last_type'].map({0: 'blue', 1: 'orange'}));

# %% [markdown]
# ## Вывод:
# удалось достичь меттрики МАЕ=5.546 на на очищенных от выбросов даннных с моделью LGBM c подобранными гиперпараметрами. В том числе построены дополнительные модели, в которые принимается в качестве признака не температура, а факт попадания в определенный диапазон, который определен эмпирически. Лучшая модель не сильно уступает предыдущей, MAE=5.95 (с нач. температурой). Дополнительно проведена визуализация с TSNE, чтобы понять где сосредоточены определенные признаки. Требования заказчика удовлетворены.

# %% [markdown]
# ### В результате работы над проектом выполнены пункты по:
# - Проведению исследовательского анализа данных, по его итогам составлен план дальнейшей работы;
# - Удалению некорректных значений целевого признака (фильтрация исходя из времени замера);
# - Суммированию всех ресурсов по партии и использование его, как новый признак;
# - Построению различных моделей машинного обучения и оценить их качество на отложенной выборке по метрике MAE;
# - Проведению отбора признаков и определия их важности, топ 3 - Нач. температура, Активная мощьность, ;
# - Построению моделей с разными признаками: активная мощность, время нагрева в секундах, полная работа. Полная мощность (сумма активной и реактивной мощностей) не была использована, т.к. опытным путем было определено, что реактивная мощность не несет в себе пользы для моделей предсказания;
# - У всех моделей удалось оценить их качество на отложенной выборке по метрике MAE: наименьшее значение у модели LGBM на очищенных от выбросов данных (значение 5.546). Дополнительно построена  модель, в которые принимается в качестве признака не начальная температура, а факт попадания в определенный диапазон, который определен эмпирически. Лучшая модель LGBM не сильно уступает предыдущей, MAE=5.95 Модель поможет нам повысить энергоэффективность производства;
# - Из трудностей было написание кода по удалению некорректных значений целевого признака, а также объединение всех исходных таблиц в одну. Они были преодолены путем написания разных вариантов кода и анализа их правильности в работе;
# - Ключевыми шагами я считаю исследовательского анализа данных, генерация и апробация новых фичей, построение обучающей выборки и различных ML моделей, анализ их качества, определение важности признаков в лучшей модели;
# - Итоговая модель - LGBM на очищенных от выбросов данных (значение МАЕ = 5.546).
