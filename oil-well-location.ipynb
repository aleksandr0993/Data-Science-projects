# %%
import os

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # Выбор локации для скважины
#
# Допустим, вы работаете в добывающей компании «ГлавРосГосНефть». Нужно решить, где бурить новую скважину.\
# Шаги для выбора локации обычно такие:\
# В избранном регионе собирают характеристики для скважин: качество нефти и объём её запасов;\
# Строят модель для предсказания объёма запасов в новых скважинах;\
# Выбирают скважины с самыми высокими оценками значений;\
# Определяют регион с максимальной суммарной прибылью отобранных скважин.\
# Вам предоставлены пробы нефти в трёх регионах. Характеристики для каждой скважины в регионе уже известны. Постройте модель для определения региона, где добыча принесёт наибольшую прибыль. Проанализируйте возможную прибыль и риски техникой Bootstrap.

# %% [markdown]
# ### Загрузим и подготовим данные.

# %%
def load_dataset(name, **kwargs):
    """Читает датасет из локальной папки datasets/, при её отсутствии — с code.s3.yandex.net."""
    local = os.path.join('datasets', name)
    source = local if os.path.exists(local) else 'https://code.s3.yandex.net/datasets/' + name
    return pd.read_csv(source, **kwargs)

df1 = load_dataset('geo_data_0.csv')
df1.head()
# Out:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647

# %%
df1['id'].value_counts()
# Out:
# id
# HZww2    2
# bxg6G    2
# QcMuo    2
# A5aEY    2
# fiKDv    2
#         ..
# DLsed    1
# QKivN    1
# 3rnvd    1
# 7kl59    1
# 1CWhH    1
# Name: count, Length: 99990, dtype: int64

# %%
df1[df1['id']=='bsk9y']
# Out:
#           id        f0        f1         f2     product
# 89582  bsk9y  0.398908 -0.400253  10.122376  163.433078
# 97785  bsk9y  0.378429  0.005837   0.160827  160.637302

# %%
df1.drop_duplicates(subset='id', inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 99990 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       99990 non-null  str
#  1   f0       99990 non-null  float64
#  2   f1       99990 non-null  float64
#  3   f2       99990 non-null  float64
#  4   product  99990 non-null  float64
# dtypes: float64(4), str(1)
# memory usage: 4.6 MB

# %%
df1.describe()
# Out:
#                  f0            f1            f2       product
# count  99990.000000  99990.000000  99990.000000  99990.000000
# mean       0.500454      0.250141      2.502629     92.499684
# std        0.871844      0.504430      3.248149     44.288304
# min       -1.408605     -0.848218    -12.088328      0.000000
# 25%       -0.072572     -0.200877      0.287784     56.497069
# 50%        0.502405      0.250252      2.515969     91.847928
# 75%        1.073626      0.700640      4.715035    128.563699
# max        2.362331      1.343769     16.003790    185.364347

# %%
df2 = load_dataset('geo_data_1.csv')
df2.head()
# Out:
#       id         f0         f1        f2     product
# 0  kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1  62mP7  14.272088  -3.475083  0.999183   26.953261
# 2  vyE1P   6.263187  -5.948386  5.001160  134.766305
# 3  KcrkZ -13.081196 -11.506057  4.999415  137.945408
# 4  AHL4O  12.702195  -8.147433  5.004363  134.766305

# %%
df2.drop_duplicates(subset='id', inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 99996 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       99996 non-null  str
#  1   f0       99996 non-null  float64
#  2   f1       99996 non-null  float64
#  3   f2       99996 non-null  float64
#  4   product  99996 non-null  float64
# dtypes: float64(4), str(1)
# memory usage: 4.6 MB

# %%
df2.describe()
# Out:
#                  f0            f1            f2       product
# count  99996.000000  99996.000000  99996.000000  99996.000000
# mean       1.141209     -4.796608      2.494501     68.823916
# std        8.965815      5.119906      1.703579     45.944663
# min      -31.609576    -26.358598     -0.018144      0.000000
# 25%       -6.298551     -8.267985      1.000021     26.953261
# 50%        1.153055     -4.813172      2.011475     57.085625
# 75%        8.620964     -1.332816      3.999904    107.813044
# max       29.421755     18.734063      5.019721    137.945408

# %%
df3 = load_dataset('geo_data_2.csv')
df3.head()
# Out:
#       id        f0        f1        f2     product
# 0  fwXo0 -1.146987  0.963328 -0.828965   27.758673
# 1  WJtFt  0.262778  0.269839 -2.530187   56.069697
# 2  ovLUW  0.194587  0.289035 -5.586433   62.871910
# 3  q6cA6  2.236060 -0.553760  0.930038  114.572842
# 4  WPMUX -0.515993  1.716266  5.899011  149.600746

# %%
df3.drop_duplicates(subset='id', inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 99996 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       99996 non-null  str
#  1   f0       99996 non-null  float64
#  2   f1       99996 non-null  float64
#  3   f2       99996 non-null  float64
#  4   product  99996 non-null  float64
# dtypes: float64(4), str(1)
# memory usage: 4.6 MB

# %%
df3.describe()
# Out:
#                  f0            f1            f2       product
# count  99996.000000  99996.000000  99996.000000  99996.000000
# mean       0.002002     -0.002159      2.495084     94.998342
# std        1.732052      1.730397      3.473482     44.749573
# min       -8.760004     -7.084020    -11.970335      0.000000
# 25%       -1.162328     -1.174841      0.130269     59.450028
# 50%        0.009424     -0.009661      2.484236     94.925026
# 75%        1.158477      1.163523      4.858720    130.586815
# max        7.238262      7.844801     16.739402    190.029838

# %%
df3['id'].value_counts()
# Out:
# id
# fwXo0    1
# WJtFt    1
# ovLUW    1
# q6cA6    1
# WPMUX    1
#         ..
# 4GxBu    1
# YKFjq    1
# tKPY3    1
# nmxp2    1
# V9kWn    1
# Name: count, Length: 99996, dtype: int64

# %%
sns.pairplot(df1[['f0', 'f1', 'f2', 'product']])

# %% [markdown]
# ### Обучим и проверим модель для каждого региона:

# %%
data = [df1, df2, df3]
len(data)
# Out:
# 3

# %%
# Разобьём данные каждого региона на обучающую и валидационную выборки (75:25),
# обучим линейную регрессию и сохраним предсказания
features, target, features_train, features_valid, target_train, target_valid, model, predicted, pred_true, rmse, mean = [
    [[], [], []] for _ in range(11)]
for i in range(len(data)):
    features[i] = data[i].drop(['id', 'product'], axis=1)
    target[i] = data[i]['product']
    features_train[i], features_valid[i], target_train[i], target_valid[i] = train_test_split(
        features[i], target[i], test_size=0.25, random_state=12345)
    model[i] = LinearRegression()
    model[i].fit(features_train[i], target_train[i])
    # сохраним предсказания и правильные ответы на валидационной выборке
    predicted[i] = model[i].predict(features_valid[i])
    pred_true[i] = pd.concat([pd.Series(predicted[i]), pd.Series(target_valid[i])],
                             axis=1, ignore_index=True, join='inner')
    rmse[i] = mean_squared_error(target_valid[i], predicted[i]) ** 0.5
    mean[i] = predicted[i].mean()
    print("MAE на обучающей выборке для региона {:>10}: ".format(i + 1),
          mean_absolute_error(target_train[i], model[i].predict(features_train[i])))
    print("MAE на валидационной выборке для региона {:>6}: ".format(i + 1),
          mean_absolute_error(target_valid[i], model[i].predict(features_valid[i])))
    print("R2 на обучающей выборке для региона {:>11}: ".format(i + 1),
          r2_score(target_train[i], model[i].predict(features_train[i])))
    print("R2 на валидационной выборке для региона {:>7}: ".format(i + 1),
          r2_score(target_valid[i], model[i].predict(features_valid[i])))
    print('.......................................................................')
# Out:
# MAE на обучающей выборке для региона          1:  30.99364389232966
# MAE на валидационной выборке для региона      1:  31.141028675220266
# R2 на обучающей выборке для региона           1:  0.27673319820995035
# R2 на валидационной выборке для региона       1:  0.2723923460817067
# .......................................................................
# MAE на обучающей выборке для региона          2:  0.7167518849084024
# MAE на валидационной выборке для региона      2:  0.7193530096516099
# R2 на обучающей выборке для региона           2:  0.9996251255768347
# R2 на валидационной выборке для региона       2:  0.9996222988190184
# .......................................................................
# MAE на обучающей выборке для региона          3:  32.808270307667705
# MAE на валидационной выборке для региона      3:  32.83139014902301
# R2 на обучающей выборке для региона           3:  0.1998431743734126
# R2 на валидационной выборке для региона       3:  0.19556241810202357
# ...

# %%
# Напечатаем на экране средний запас предсказанного сырья и RMSE модели
for i in range(len(data)):
    print("  Средний запас предсказанного сырья для модели региона {}: {:.2f}, RMSE: {:.2f}".format(i+1, mean[i], rmse[i]))
# Out:
#   Средний запас предсказанного сырья для модели региона 1: 92.79, RMSE: 37.85
#   Средний запас предсказанного сырья для модели региона 2: 69.18, RMSE: 0.89
#   Средний запас предсказанного сырья для модели региона 3: 94.87, RMSE: 40.08

# %%
# Константная модель (проверка на адекватность): предсказываем медиану обучающей выборки региона
for i in range(len(data)):
    med = target_train[i].median()
    print("MAE константной модели на валидационной выборке для региона {:>6}: ".format(i + 1),
          mean_absolute_error(target_valid[i], [med] * len(target_valid[i])))
# Out:
# MAE константной модели на валидационной выборке для региона      1:  37.78923861936353
# MAE константной модели на валидационной выборке для региона      2:  40.273437504372644
# MAE константной модели на валидационной выборке для региона      3:  37.757163088120144

# %% [markdown]
# #### Проанализируем результаты
# 1-я и 3-я модели имеют высокое значение ошибки предсказания и одновременно предсказывают большие, в сравнении со 2-й моделью, запасы нефти. 2-я модель имеет низкое значение ошибки предсказания.
#
# Обратим внимание на аномально высокий R² ≈ 1.0 во втором регионе: признак `f2` в этих (синтетических) данных почти функционально связан с целевым `product`, поэтому линейная регрессия восстанавливает его практически без ошибки. В реальных геологических данных такое поведение было бы поводом проверить утечку целевого признака.

# %% [markdown]
# ### Подготовка к расчёту прибыли

# %% [markdown]
# #### Cохранение ключевых значений в отдельных переменных.

# %%
UNIT_COST = 450 * 1e3 # цена за единицу нефти

# %%
INCOME = 200 * UNIT_COST # прибыль от 200  скважин

# %%
EXPENSE = 10 * 1e9 # расходы

# %%
#прибыль
PROFIT = INCOME - EXPENSE

# %% [markdown]
# #### Рассчитаем достаточный объём сырья для безубыточной разработки новой скважины. Сравним полученный объём сырья со средним запасом в каждом регионе.

# %%
ENOUGH_VOLUME = (EXPENSE/200) / UNIT_COST
ENOUGH_VOLUME
# Out:
# 111.11111111111111

# %% [markdown]
# #### Выводы по этапу подготовки расчёта прибыли: рассчитаны ключевые значения для нахождения прибыли при выборе и разработке региона.

# %% [markdown]
# ### Напишем функцию для расчёта прибыли по выбранным скважинам и предсказаниям модели:

# %%
def profit(target, probabilities, count):
    probs_sorted = probabilities.sort_values(ascending=False)
    selected = target[probs_sorted.index][:count]
    return (UNIT_COST * selected.sum() - EXPENSE)

# %% [markdown]
# ### Посчитаем риски и прибыль для каждого региона:

# %% [markdown]
# #### Применим технику Bootstrap с 1000 выборок, чтобы найти распределение прибыли и риск убытков:

# %%
probabilities, values = [[[], [], []] for _ in range(2)]
for i in range(len(data)):
    count = 0
    state = np.random.RandomState(12345)
    target_bs = pd.Series(target_valid[i].reset_index(drop=True))
    probabilities[i] = pd.Series(predicted[i])
    values[i] = []
    for j in range(1000):
        subsamples_t = target_bs.sample(n=500, random_state=state, replace=True)
        subsamples_pr = probabilities[i][subsamples_t.index]
        val = profit(subsamples_t, subsamples_pr, 200)
        values[i].append(val)
        if val < 0:
            count += 1
    risk = count / 1000 * 100
    # средняя прибыль и 95%-й доверительный интервал
    lower = pd.Series(values[i]).quantile(0.025)
    upper = pd.Series(values[i]).quantile(0.975)
    print('Риск убытков в регионе {}: {:.1f} %'.format(i + 1, risk))
    print('Средняя прибыль в регионе {}: {:.1f} млн руб.'.format(i + 1, pd.Series(values[i]).mean() / 1e6))
    print('Нижняя граница 95%-го доверительного интервала в регионе {}: {:.1f} млн руб.'.format(i + 1, lower / 1e6))
    print('Верхняя граница 95%-го доверительного интервала в регионе {}: {:.1f} млн руб.'.format(i + 1, upper / 1e6))
    print('............................................................')
# Out:
# Риск убытков в регионе 1: 7.1 %
# Средняя прибыль в регионе 1: 409.4 млн руб.
# Нижняя граница 95%-го доверительного интервала в регионе 1: -131.5 млн руб.
# Верхняя граница 95%-го доверительного интервала в регионе 1: 944.4 млн руб.
# ............................................................
# Риск убытков в регионе 2: 0.9 %
# Средняя прибыль в регионе 2: 536.9 млн руб.
# Нижняя граница 95%-го доверительного интервала в регионе 2: 114.5 млн руб.
# Верхняя граница 95%-го доверительного интервала в регионе 2: 970.8 млн руб.
# ............................................................
# Риск убытков в регионе 3: 10.2 %
# Средняя прибыль в регионе 3: 353.8 млн руб.
# Нижняя граница 95%-го доверительного интервала в регионе 3: -159.2 млн руб.
# Верхняя граница 95%-го доверительного интервала в регионе 3: 875.7 млн руб.
# ............................................................

# %% [markdown]
# #### Выводы: предложение региона для разработки
# Рассчитаны 95%-й доверительный интервал, средняя прибыль и риск убытков для каждого региона. По результатам расчётов во 2-м регионе доверительный интервал прибыли полностью расположен в области положительных значений, а риск убытков ниже допустимых 2.5%, чего нельзя сказать про 1-й и 3-й регионы.
#
# **Выбираем для разработки 2-й регион**: наибольшая средняя прибыль при минимальном риске убытков.
